# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')
iris = sns.load_dataset('iris')
titanic = sns.load_dataset('titanic')
planets = sns.load_dataset('planets')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(6,3))
sns.scatterplot(x='tip',y='total_bill',data=tips)
plt.show()

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
plt.figure(figsize=(6,3))
sns.scatterplot(x='tip',y='total_bill',data=tips,hue='day')
plt.show()

# %%
tips['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='tip',y='total_bill',data=tips,hue='day',size='size')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(x='tip',y='total_bill',data=tips,hue='day',size='size',palette='viridis')
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.histplot(tips.tip)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.histplot(tips.tip,kde=True)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.distplot(tips.tip,kde=True)
plt.show()
# Out:
# C:\Users\saini\AppData\Local\Temp\ipykernel_13656\426771254.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips.tip,kde=True)

# %%
plt.figure(figsize=(4,3))
sns.displot(tips.tip,kde=True)
plt.show()

# %%
sns.displot(tips.tip,kde=True)

# %%
# KDE => Kernal Density Estimation

# %%
plt.figure(figsize=(5,3))
sns.boxplot(tips.tip)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.barplot(x='sex',y='tip',data=tips,palette='viridis')
plt.show()
# Out:
# C:\Users\saini\AppData\Local\Temp\ipykernel_13656\1065899278.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='sex',y='tip',data=tips,palette='viridis')

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x='sex',y='tip',data=tips,palette='viridis')
plt.show()
# Out:
# C:\Users\saini\AppData\Local\Temp\ipykernel_13656\1117126660.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='sex',y='tip',data=tips,palette='viridis')

# %%
tips.groupby(['sex']).agg({'tip':'count'})
# Out:
# C:\Users\saini\AppData\Local\Temp\ipykernel_13656\151668638.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby(['sex']).agg({'tip':'count'})
#         tip
# sex
# Male    157
# Female   87

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x='day',y='tip',data=tips,palette='viridis')
plt.show()
# Out:
# C:\Users\saini\AppData\Local\Temp\ipykernel_13656\731453521.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='day',y='tip',data=tips,palette='viridis')

# %%
plt.figure(figsize=(5,3))
sns.boxplot(x='day',y='tip',hue='sex',data=tips,palette='viridis')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.stripplot(x='day',y='tip',hue='sex',data=tips,palette='viridis')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.stripplot(x='day',y='tip',hue='sex',data=tips,dodge=True,palette='viridis')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.jointplot(x='tip',y='total_bill',data=tips)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.jointplot(x='tip',y='total_bill',kind='reg',data=tips)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.jointplot(x='tip',y='total_bill',kind='kde',data=tips)
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.jointplot(x='tip',y='total_bill',kind='kde',shade=True,data=tips)
plt.show()
# Out:
# C:\Users\saini\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
plt.figure(figsize=(5,3))
sns.jointplot(x='tip',y='total_bill',kind='kde',shade=True,data=tips,cmap='viridis')
plt.show()
# Out:
# C:\Users\saini\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
plt.figure(figsize=(5,3))
sns.jointplot(x='tip',y='total_bill',kind='kde',data=tips,cmap='viridis')
plt.show()

# %%
plt.figure(figsize=(5,3))
sns.jointplot(x='tip',y='total_bill',kind='hist',data=tips,cmap='viridis')
plt.show()

# %%
titanic.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
titanic.select_dtypes(include=np.number).columns
# Out:
# Index(['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare'], dtype='object')

# %%
sns.pairplot(titanic.select_dtypes(include=np.number),hue='pclass')

# %%
titanic = titanic.select_dtypes(include=np.number)

# %%
titanic.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(titanic.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(titanic.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(titanic.corr(),annot=True,cmap='viridis')
# Out:
# <Axes: >
